# %% [markdown]
# **NOTA:** Ejecutar el notebook en una GPU ayudará a un proceso de entrenamiento mucho más eficiente.
#
# En este ejercicio, definiremos, entrenaremos y utilizaremos una arquitectura de red neuronal convolutiva (CNN) para la clasificación de imágenes en el conjunto de datos [CIFAR](https://www.cs.toronto.edu/~kriz/cifar.html), que contiene imágenes en color de baja resolución.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# El conjunto de datos contiene imágenes a color de objetos de 10 tipos diferentes, por lo que formularemos el problema de aprendizaje como una clasificación bajo 10 clases.
#
# Comenzamos por descargarlo y separamos las entradas y salidas de entrenamiento y prueba, asegurándonos de que las etiquetas de clase (enteros) se consideren categóricas y no numéricas a efectos de la red neuronal que se construirá.

# %% [markdown]
# Construiremos el modelo capa por capa, con una arquitectura similar a lo aprendido en clase sobre arquitecturas de redes neuronales convolutivas:

# %% [markdown]
# Compilar y entrenar el modelo

# %% [markdown]
# Evaluar el modelo entrenado con el conjunto de prueba

# %% [markdown]
# Predicciones de prueba:

# %% [markdown]
# **Código auxiliar** para visualizar algunas (¡10 elegidas al azar!) predicciones hechas frente a las clases reales de las imágenes, mostrando varios ejemplos de imágenes.
