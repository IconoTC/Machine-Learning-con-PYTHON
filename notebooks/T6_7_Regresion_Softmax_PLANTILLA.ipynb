# %% [markdown]
# Este ejemplo utiliza un **modelo de regresión softmax** para la clasificación en el conjunto de datos *iris*. A diferencia de la regresión logística, que se limitaba a tareas de clasificación binaria, con un regresor softmax podemos realizar predicciones sobre las tres clases originales del conjunto de datos de flores iris.
#
# * Etiqueta **0.0** para *iris setosa*.
# * Etiqueta **1.0** para *iris versicolor*.
# * Etiqueta **2.0** para *iris virgínica*.

# %% [markdown]
# En *scikit-learn*, se entrena un regresor softmax con la clase *LogisticRegression*, añadiendo un par de ajustes sencillos.
#
# 1. Establecemos el parámetro de inicialización de la clase *multi_class="multinomial"*:
# 2. **Nos aseguramos** de usar solo un método de optimización subyacente (*solver*) compatible con la regresión softmax, por ejemplo, "*lbfgs*" (predeterminado). No todos los *solvers* disponibles en la clase *LogisticRegression* son compatibles con los regresores softmax.

# %% [markdown]
# Realizamos una predicción de prueba con una observación que tiene una longitud de pétalo de 4.5cm y anchura de pétalo de 2.3cm:

# %% [markdown]
# Obtener las probabilidades estimadas de pertenecer a cada una de las tres clases existentes:
